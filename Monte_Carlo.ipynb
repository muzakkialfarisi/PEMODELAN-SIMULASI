# %% [markdown]
# <a href="https://colab.research.google.com/github/muzakkialfarisi/PEMODELAN-SIMULASI/blob/monte-carlo/Monte_Carlo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 0
b = 1
n = 1000

def f(x):
  return ((x**2)-(3*(x))+(4))

fx1 = []
w = []
I_1 = []
for i in range(n):
  x = random.randint(1,9)
  fx1.append(f(x))
  w.append((b-a)/n)
  I_1.append(fx1[i]*w[i])

print('NIlai I =', I_1)
# Out:
# NIlai I = [0.008, 0.008, 0.044, 0.022, 0.032, 0.002, 0.004, 0.002, 0.004, 0.002, 0.002, 0.008, 0.004, 0.032, 0.002, 0.032, 0.014, 0.058, 0.044, 0.014, 0.032, 0.032, 0.022, 0.022, 0.058, 0.044, 0.044, 0.014, 0.004, 0.058, 0.044, 0.002, 0.004, 0.022, 0.008, 0.014, 0.022, 0.022, 0.002, 0.002, 0.032, 0.008, 0.004, 0.004, 0.002, 0.044, 0.032, 0.032, 0.008, 0.022, 0.022, 0.002, 0.002, 0.032, 0.032, 0.002, 0.002, 0.014, 0.032, 0.014, 0.044, 0.014, 0.058, 0.008, 0.008, 0.032, 0.058, 0.004, 0.022, 0.008, 0.014, 0.032, 0.008, 0.022, 0.022, 0.002, 0.058, 0.032, 0.058, 0.058, 0.004, 0.002, 0.002, 0.022, 0.022, 0.022, 0.004, 0.058, 0.008, 0.044, 0.022, 0.004, 0.002, 0.058, 0.044, 0.002, 0.044, 0.014, 0.004, 0.014, 0.022, 0.044, 0.004, 0.004, 0.032, 0.002, 0.022, 0.032, 0.032, 0.002, 0.002, 0.032, 0.002, 0.004, 0.002, 0.014, 0.002, 0.044, 0.014, 0.002, 0.022, 0.002, 0.058, 0.022, 0.002, 0.008, 0.004, 0.032, 0.032, 0.008, 0.022, 0.022, 0.004, 0.004, 0.008, 0.014, 0.032, 0.004, 0.022, 0.044, 0.002, 
# ...

# %%
from scipy.stats import norminvgauss as norminv

a = 0
b = 1
n = 1000

fx2 = []
var_f = []

for i in range(n):
  x = random.uniform(-1,1)
  fx2.append(f(x))

f_topi = sum(fx2)/n

for i in range(n):
  var_f.append(((fx2[i]-f_topi)**2)/(n-1))

rata_var_f = sum(var_f)/n

K = norminv.pdf(0,1,0,0.95)

b_bawah = (b-a)*(f_topi - (K * rata_var_f))
b_atas = (b-a)*(f_topi + (K * rata_var_f))

print(b_bawah,' <= I <= ',b_atas )
# Out:
# 4.269935541937084  <= I <=  4.271182149351617
